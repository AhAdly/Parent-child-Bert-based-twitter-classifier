# %%
import arguebuf as ag
import random

# %%
import os
def get_all_files(directory):
    file_list = []
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        if os.path.isdir(filepath):
            # If the file is a directory, recursively call this function
            file_list.extend(get_all_files(filepath))
        else:
            # If the file is a file, add it to the list
            if os.path.splitext(filepath)[1] == ".json":
                file_list.append(filepath)
    return file_list

# Call the function with the directory path you want to list
files = get_all_files('Full Un-anottated data/')

# %%
tweet_id_graph_dict = dict()
parent_child_tweets = {"parent": [], "child": []}

for i, f in enumerate(files):
    
    # create a dictionary for each file with the key = i (index in the list of files)
    tweet_id_graph_dict[i] = dict()
    
    # same as previous, but just with identiying list of parents and list of childs for each file
 #   parent_child_tweets[i] = {"parent": [], "child": []}
    
    # read file using arguebuf library
    graph = ag.Graph.from_file(f)

    # loop on values of each file and save the label (tweet) as value and id as key within each file
    for node in graph.atom_nodes.values():
        tweet_id_graph_dict[i][node.id] = node.label
    
    # loop on each file items and save all related child and parents in the lists
    # also add them to a set so no values are repeated
#     print(f)
    for key, value in graph.scheme_nodes.items():
       # print(i)
      #  print("key".ljust(10), key)
      #  print("value".ljust(10), value)
        
        child_tweet_id = key.split(',')[0]
        parent_tweet_id = key.split(',')[1]
        
        parent_child_tweets["parent"].append(tweet_id_graph_dict[i][parent_tweet_id])
        parent_child_tweets["child"].append(tweet_id_graph_dict[i][child_tweet_id])

# %%
import pandas as pd
df = pd.DataFrame(parent_child_tweets)
df = df.drop_duplicates().reset_index(drop=True)

# %%
# Shuffle and reset index, to make sure it's randomized
df = df.sample(frac=1).reset_index(drop=True)

# %%
# Get a random sample of the DataFrame
first_df = df.sample(frac=0.5)

# Drop the sampled rows from the original DataFrame
second_df = df.drop(first_df.index)

# %%
first_df["label"] = 1
first_df.head()
# Out:
#                                                    parent  \
# 209622  ⚠️BREAKING—Huge CDC study says #COVID19 not on...
# 109081  .@realDonaldTrump was the clear winner in last...
# 189860  President Trump arrives in Fort Myers, Florida...
# 154200    “Learn” - a word still not understood by trump.
# 78050          I’m voting for America #vote #election2020
#
#                                                     child  label
# 209622  As best as I can tell, this excess deaths stor...      1
# 109081                         You’re clearly delusional.      1
# 189860                       Death cult. How many today??      1
# 154200                                         Damn right      1
# 78050   You have no idea what real Americans look or s...      1

# %%
first_df = first_df.rename(columns={"parent": "input1", "child": "input2"})
first_df.head()
# Out:
#                                                    input1  \
# 209622  ⚠️BREAKING—Huge CDC study says #COVID19 not on...
# 109081  .@realDonaldTrump was the clear winner in last...
# 189860  President Trump arrives in Fort Myers, Florida...
# 154200    “Learn” - a word still not understood by trump.
# 78050          I’m voting for America #vote #election2020
#
#                                                    input2  label
# 209622  As best as I can tell, this excess deaths stor...      1
# 109081                         You’re clearly delusional.      1
# 189860                       Death cult. How many today??      1
# 154200                                         Damn right      1
# 78050   You have no idea what real Americans look or s...      1

# %%
second_df.head()
# Out:
#                                               parent  \
# 0  Today is your last chance to register to vote ...
# 1  OMG! Who did this?!?! Best 2 minutes of your d...
# 3  OMG! Who did this?!?! Best 2 minutes of your d...
# 5  BREAKING—New records reveal that, while Trump ...
# 7  President Trump won't have to recover from COV...
#
#                                                child
# 0  Go AZ for Biden! We can change the color of th...
# 1                Omg.. This is the best clip ever. 🎉
# 3                       Absolutely loved it awesome!
# 5  its pretty fucked up but also I feel like if y...
# 7  Have you taken your temp? Only someone serious...

# %%
second_df = second_df[["child", "parent"]]
second_df.head()
# Out:
#                                                child  \
# 0  Go AZ for Biden! We can change the color of th...
# 1                Omg.. This is the best clip ever. 🎉
# 3                       Absolutely loved it awesome!
# 5  its pretty fucked up but also I feel like if y...
# 7  Have you taken your temp? Only someone serious...
#
#                                               parent
# 0  Today is your last chance to register to vote ...
# 1  OMG! Who did this?!?! Best 2 minutes of your d...
# 3  OMG! Who did this?!?! Best 2 minutes of your d...
# 5  BREAKING—New records reveal that, while Trump ...
# 7  President Trump won't have to recover from COV...

# %%
second_df = second_df.rename(columns={"child": "input1", "parent": "input2"})
second_df["label"] = 0
second_df.head()
# Out:
#                                               input1  \
# 0  Go AZ for Biden! We can change the color of th...
# 1                Omg.. This is the best clip ever. 🎉
# 3                       Absolutely loved it awesome!
# 5  its pretty fucked up but also I feel like if y...
# 7  Have you taken your temp? Only someone serious...
#
#                                               input2  label
# 0  Today is your last chance to register to vote ...      0
# 1  OMG! Who did this?!?! Best 2 minutes of your d...      0
# 3  OMG! Who did this?!?! Best 2 minutes of your d...      0
# 5  BREAKING—New records reveal that, while Trump ...      0
# 7  President Trump won't have to recover from COV...      0

# %%
df = pd.concat([first_df, second_df])
df
# Out:
#                                                    input1  \
# 209622  ⚠️BREAKING—Huge CDC study says #COVID19 not on...
# 109081  .@realDonaldTrump was the clear winner in last...
# 189860  President Trump arrives in Fort Myers, Florida...
# 154200    “Learn” - a word still not understood by trump.
# 78050          I’m voting for America #vote #election2020
# ...                                                   ...
# 305943  He called us losers for serving the country. T...
# 305948  That's the problem with my fellow black brothe...
# 305949  We start early voting tomorrow in SWFL. I’ll b...
# 305955  If you want freedom of choice you're voting fo...
# 305957                                        Fuck Trump!
#
#                                                    input2  label
# 209622  As best as I can tell, this excess deaths stor...      1
# 109081                         You’re clearly delusional.      1
# 189860                       Death cult. How many today??      1
# 154200                                         Damn right      1
# 78050   You have no idea what real Americans look or s...      1
# ...                                                   ...    ...
# 305943  My Vote is for what makes this country great, ...      0
# 305948  That’s because the best thing about the Republ...      0
# 305949  Don’t wait for Election Day to vote. If you’re...      0
# 305955  My Vote is for what makes this country great, ...      0
# 305957  My Vote is for what makes this country great, ...      0
#
# [305958 rows x 3 columns]

# %%
df = df.sort_index()
df
# Out:
#                                                    input1  \
# 0       Go AZ for Biden! We can change the color of th...
# 1                     Omg.. This is the best clip ever. 🎉
# 2       .@realDonaldTrump was the clear winner in last...
# 3                            Absolutely loved it awesome!
# 4       JUST IN: @KamalaHarris canceling her campaign ...
# ...                                                   ...
# 305953  POTUS still going in Janesville, Wisconsin!! #...
# 305954  My Vote is for what makes this country great, ...
# 305955  If you want freedom of choice you're voting fo...
# 305956  3) “Congressional Dems have grown so frustrate...
# 305957                                        Fuck Trump!
#
#                                                    input2  label
# 0       Today is your last chance to register to vote ...      0
# 1       OMG! Who did this?!?! Best 2 minutes of your d...      0
# 2       covidbrain is real, but this guy was never too...      1
# 3       OMG! Who did this?!?! Best 2 minutes of your d...      0
# 4       How can that be when they are following the CD...      1
# ...                                                   ...    ...
# 305953  Isn't this the 3rd Peaceful Protest today for ...      1
# 305954  Hmm ..all the things you mentioned-Biden suppo...      1
# 305955  My Vote is for what makes this country great, ...      0
# 305956    and she better not cave without these in place.      1
# 305957  My Vote is for what makes this country great, ...      0
#
# [305958 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 305958 entries, 0 to 305957
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   input1  305958 non-null  object
#  1   input2  305958 non-null  object
#  2   label   305958 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 9.3+ MB

# %%
df.to_csv("data.csv", index=False)
